# %% [markdown]
# # Age specific Fertility Rate(ASFR)

# %% [markdown]
# ## Per Individual Age - 2017

# %% [markdown]
# Source - Births registrations and Population Estimates for UK, England and Wales, Scotland and Northern Ireland: Mid-2017
# Produced by Demographic Analysis Unit, Office for National Statistics
# pop.info@ons.gov.uk
#
# Notes:
# 1. The age specific fertility rate (ASFR) is the number of live births per 1,000 women at each age
# 2. Age 14 comprises of 14 and under
# 3. Total given for age 45 is sum of 45 and over
# 4. It is important that the Office for National Statistics ensures that these statistics meet the needs of the people who use them. The Office for National Statistics would appreciate feedback on the uses and usefulness of the information provided.
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
import vivarium, vivarium_public_health

# %%
asfrindv2017 = pd.read_csv("../vivarium_public_health_spenser/persistant_data/asfr_indv_ages_2017.csv")

# %%
asfrindv2017
# Out:
#     Age        Rate
# 0    14    0.233926
# 1    15    1.040012
# 2    16    3.551350
# 3    17   10.235427
# 4    18   17.541531
# 5    19   28.850013
# 6    20   38.738826
# 7    21   45.403373
# 8    22   54.447602
# 9    23   60.029377
# 10   24   68.555022
# 11   25   77.051545
# 12   26   86.075332
# 13   27   98.055660
# 14   28  104.818597
# 15   29  110.359518
# 16   30  113.198479
# 17   31  115.957704
# 18   32  114.020226
# 19   33  106.901325
# 20   34   98.579853
# 21   35   88.818871
# 22   36   76.922107
# 23   37   64.197083
# 24   38   51.626196
# 25   39   41.111822
# 26   40   30.038306
# 27   41   20.658250
# 28   42   13.102931
# 29   43    7.518166
# 30   44    4.254257
# 31   45    5.879404

# %%
sb.set_style("darkgrid")
sb.lineplot(x="Age", y="Rate", data=asfrindv2017)

# %% [markdown]
# Rate
